# %% [markdown]
# # Языки программирования

# %% [markdown]
# Существует большое разнообразие языков программирования, предназначенных для реализации вычислительных процессов и преобразования информации. Но сегодня активно применяется только небольшая часть из них, остальные языки стали историей и считаются мертвыми.
#
# Голландская компания [TIOBE Software BV](http://www.tiobe.com/) в первую очередь известна как автор регулярно рассчитываемого [рейтинга популярности языков программирования](https://www.tiobe.com/tiobe-index/). Рейтинг TIOBE рассчитывается начиная с июня 2001 года. Первоначально он включал 25 языков программирования. В настоящее время в рейтинге учитываются 150 языков программирования. Измерения проводятся не менее 10 раз в месяц.

# %% [markdown]
# Деление языков программирования на две группы:
# - компилируемые языки
# - интерпретируемые (скриптовые) языки

# %% [markdown]
# Выбор новичка:
# - локаничный синтаксис
# - обновляемая документация
# - простая среда разработки
# - готовые библиотеки
# - работа на любой платформе
# - ### все бесплатно!!!

# %% [markdown]
# # Язык программирования Python

# %% [markdown]
# Python — это активно развивающийся скриптовый язык, который используют для решения большого объема самых разноплановых проблем и задач.
#
# Области использования:
# - создание Desktop и мобильных приложений (библиотека Tkinter).
# - разработка ПО для встраиваемых систем (Raspberry Pi).
# - создание игр (фреймворк PyGame).
# - веб-разработка (фреймворки Flask, Django).
# - анализ данных и машинное обучение (библиотеки NumPy, scikit-learn, TensorFlow, pyTorch).
# - скриптинг.

# %% [markdown]
# `Программная библиотека` - набор подпрограмм (модулей) близкой функциональности.
#
# `Фреймворк` - "каркас" программного приложения, который диктует правила его построения, архитектуру и поведение.

# %% [markdown]
# Разработчиком языка является сотрудник голландского института Гвидо ван Россум, который писал такой язык в свободное время и первый код был опубликован в 1991 году.
#
# <img src="https://avatars.mds.yandex.net/get-zen_doc/1889318/pub_5f872f3a17c9884cd30be8c0_5f872faeaa68813be1771c8e/scale_1200" width="300px">

# %% [markdown]
# Распространенность языка обусловлена его преимуществами:
#
# - Язык характеризуется логичным синтаксисом.
#
# - Условная легкость.
#
# - Большое интернет-сообщество.
#
# - Python является интерпретируемым языком программирования.
#
# - Интерпретатор CPython является кроссплатформенным.

# %% [markdown]
# # Среда программирования (IDE)

# %% [markdown]
# `Интегрированная среда разработки (англ. Integrated Development Environment)` — система программных средств, используемая программистами для разработки программного обеспечения. Она обычно содержит:
# - текстовый редактор;
# - компилятор и / или интерпретатор;
# - средства автоматизации сборки;
# - отладчик.

# %% [markdown]
# Наиболее популярные IDE для программирования на Python: [Spyder](https://github.com/spyder-ide/spyder), [PyCharm](https://www.jetbrains.com/pycharm/), [Visual Studio Code](https://code.visualstudio.com/)

# %% [markdown]
# Для программирования на Python можно использовать не только локально установленные среды программирования (IDE), но и облачные сервисы.
#
# При работе с сервисами программный код, который вы набираете исполняется на виртуальной машине с интерпретатором Python. Все взаимодействие выполняется через браузер. В браузере также отображается результат исполнения кода.
#
# Такая среда лучше всего подходит новичкам, из-за простоты работы. Единственный недостаток - такие сервисы программирования на Python не поддерживают режим отладки программ.
#
# Для получения практических навыков программирования мы будем использовать сервис Google Colab для исполнения кода на Python и формат блокнотов Jupyter - для оформления результатов.
#
# Для полноценной работы с сервисом Google Colab необходимо иметь аккаунт Google.

# %% [markdown]
# # Регистрация аккаунта Google

# %% [markdown]
# Дальнейшие действия позволяют создано новый аккаунт Google. Если у вас его нет – то проделайте все эти операции.
#
# Перейдите по [ссылке](https://accounts.google.com/) (https://accounts.google.com/) на страницу входа Google и нажмите на кнопку «Создать аккаунт». Выберите в выпадающем списке создание аккаунта для себя.

# %% [markdown]
# ![Рисунок1.png](data:image/png;base64,...)

# %% [markdown]
# Следующим шагом заполните все поля на странице регистрации. Придумайте уникальное имя пользователя и пароль и нажмите кнопку Далее.

# %% [markdown]
# ![Рисунок2.png](data:image/png;base64,...)

# %% [markdown]
# Введите номер телефона и подтвердите присланным через СМС кодом владение этим номером.

# %% [markdown]
# ![Рисунок3.png](data:image/png;base64,...)

# %% [markdown]
# Для завершения регистрации укажите дату рождения и пол.

# %% [markdown]
# ![Рисунок4.png](data:image/png;base64,...)

# %% [markdown]
# На следующем шаге можно нажать кнопку «Пропустить», а в разделе «Конфиденциальность и Условия использования» нажмите кнопку «Принимаю».

# %% [markdown]
# ![Рисунок5.png](data:image/png;base64,...)

# %% [markdown]
# После выполнения этих шагов будет создан аккаунт Google с заданным именем и паролем для входа. К этому аккаунту будет привязан указанный вами номер телефона. Это на случай восстановления доступа.

# %% [markdown]
# # Jupyter Notebook (блокноты Jupyter)

# %% [markdown]
# `Jupyter Notebook` — это среда разработки, где сразу можно видеть результат выполнения кода и его отдельных фрагментов. Отличие от традиционной среды разработки в том, что код можно разбить на фрагменты (ячейки) и выполнять их в произвольном порядке. В такой среде разработки можно, например, написать функцию и сразу проверить её работу, без запуска программы целиком.
#
# Например,

# %%
x = 'Hello!'
print(x)

# %% [markdown]
# Основой среды разработки Jupyter является документ, в котором можно оформлять и программный код, и комментарии к нему в развернутом виде. Такой документ называется блокнотом Jupyter (Jupyter Notebook) и имеет расширение *.ipynb, по сравнению с обычным файлом программного кода на Python, имеющего расширение *.py.
#
# Нас больше интересует не среда разработки, а блокнот. Блокноты Jupyter Notebook мы будем использовать для подготовки материалов, создавать их или загружать их в сервис Google Colaboratory (сокращенно Google Colab) для их исполнения.

# %% [markdown]
# # Начало работы с Google Colab

# %% [markdown]
# `Google Colaboratory` или просто `Colab` – это бесплатная интерактивная облачная среда для исполнения программного кода Python на выделенной виртуальной машине. Программный код исполняется в облаке, а пользователь через браузер управляет процессом и анализирует результаты.

# %% [markdown]
# Преимущества использования такой среды, как Google Colab очевидны:
#
#
# * не требуется предварительной настройки. т.е. установки библиотек Python на свой компьютер. Это особенно важно, когда требуется работы с большими библиотеками, которые для установки требуют продолжительного времени.
# * имеется бесплатный доступ к графическим процессорам. Это важно, когда выполняются задачи большой вычислительной сложности, либо обрабатываются большие массивы данных.
# * возможность предоставлять доступ к документам другим людям. Блокноты, загруженные в Google Colab, открываются для редактирования и совместной работы другим пользователям сервисов Google.

# %% [markdown]
# Создаваемые блокноты Jupyter Notebook должны где-то храниться. Для удобства хранение можно организовать прямо в облаке. После регистрации на Google пользователю предоставляется в распоряжение хранилище файлов, которое называется Google Диск. Для подключения хранилища Google Диска перейдите по [ссылке](https://drive.google.com/drive/my-drive) (https://drive.google.com/drive/my-drive).

# %% [markdown]
# Перейдите в раздел «Настройки» (правый верхний угол экрана) и выберите раздел «Управление приложениями», «Подключить другие приложения».

# %% [markdown]
# ![Рисунок6.png](data:image/png;base64,...)

# %% [markdown]
# ![Рисунок7.png](data:image/png;base64,...)

# %% [markdown]
# В строке поиска введите Google Colab и установите это приложение.

# %% [markdown]
# ![Рисунок8.png](data:image/png;base64,...)

# %% [markdown]
# Для начала работы с Google Colab необходимо перейти по [ссылке](https://colab.research.google.com/).
#
# Нажмите на вкладку «Google Диск» и «Создать блокнот».

# %% [markdown]
# ![Рисунок9.png](data:image/png;base64,...)

# %% [markdown]
# Будет создан новый блокнот с именем «Untitled0.ipynb».

# %% [markdown]
# ![Рисунок10.png](data:image/png;base64,...)

# %% [markdown]
# Блокнот можно переименовать, дважды кликнув по заголовку.  Переименуйте файл на «Урок 1». Данный файл хранится в личном Google Диске в папке «Colab Notebooks».

# %% [markdown]
# # Интерфейс Google Colab и типы ячеек блокнота

# %% [markdown]
# Рассмотрим интерфейс Colab.

# %% [markdown]
# ![Рисунок1.png](data:image/png;base64,...)

# %% [markdown]
# По центру находится поле для ввода кода и текста.
#
# Сверху располагается горизонтальное меню для взаимодействия с файлом.

# %% [markdown]
# ![Рисунок2.png](data:image/png;base64,...)

# %% [markdown]
# ![Рисунок3.png](data:image/png;base64,...)

# %% [markdown]
# Слева располагается «Содержание», «Поиск», «Фрагменты кода» и «Файлы».

# %% [markdown]
# ![Рисунок4.png](data:image/png;base64,...)

# %% [markdown]
# Блокнот состоит из ячеек, которые являются контейнерами для теста или кода, который будет выполняться. Ячейки образуют структуру ноутбука. Существует два основных типа ячеек: ячейки кода и текстовые ячейки.
#
# Первая ячейка в новом блокноте всегда является ячейкой кода.
#
# Чтобы изменить содержимое ячейки, дважды нажмите на нее.

# %% [markdown]
# Введите код **print('Привет, мир!')**. Для исполнения кода нужно нажать Ctrl+Enter или кнопку «Запустить код» слева.
#
# В результате выполнения кода отобразится текст.

# %%
print('Привет, мир!')
# Out:
# Привет, мир!

# %% [markdown]
# Новые ячейки добавляются кнопкой «+ Код».
# Кроме кода, в проектах часто необходим сопровождающий текст: введение, оглавление, комментарии к модулям, заголовки смысловых частей. Для этого есть второй тип ячеек — текстовые.
#
# Нажмите на кнопку добавления текстовой ячейки «+ Текст». Появится ячейка, разделенная на две половины: слева поле редактора, где редактируется текст, а справа предпросмотр того, что отобразится.

# %% [markdown]
# ## Первый урок Python
#
#
# 1.   Новый пункт
# 2.   Новый пункт

# %% [markdown]
# В текстовых ячейках поддерживается популярный язык разметки Markdown. Например, заголовок в нём выделяется с помощью символов # и пробела. [Здесь](https://gist.github.com/Jekins/2bf2d0638163f1294637) можно посмотреть подробную шпаргалку на русском языке. Однако, Colab позволяет автоматически форматировать текст с помощью кнопок, расположенных в верхней части тестового блока.

# %% [markdown]
# # Оформление текстовых ячеек. Основы Markdown и LaTeX

# %% [markdown]
# В Google Colab для форматирования текстовых ячеек можно использовать:
#
#
# 1. Markdown – язык текстовой разметки.
# 2. LaTeX для визуализации математических записей.

# %% [markdown]
# ## Markdown

# %% [markdown]
# `Markdown` — это язык текстовой разметки документов. Его придумали в 2004 году блогер Джон Грубер и интернет-активист Аарон Шварц, чтобы быстро форматировать статьи. Markdown — это язык для других программ и сервисов (естественно, формализованный), чтобы они формировали документы на основе вашего текста.

# %% [markdown]
# Когда Вы добавляете в текст полужирный шрифт, курсив, нумерованные списки, маркеры, заголовки и т. д., Вы «форматируете» его. Markdown – это синтаксис или набор правил, который форматирует текст на веб-страницах.
#
# Традиционно для форматирования текста на веб-страницах использовался язык разметки гипертекста, более известный как HTML. Чтобы отформатировать текст с помощью HTML, Вы должны разместить теги вокруг текста. Например, если хотите выделить текст <b>жирным</b>, введите «< b> какой-то жирный текст < /b>». Однако теги затрудняют чтение HTML людьми и понимание того, как будет выглядеть текст после того, как компьютер его отобразит. Это не очень удобно для тех, которые не имеют большого опыта чтения HTML.
#
# Markdown упрощает форматирование текста для веб-страниц, поскольку его теги проще, чем HTML, и они автоматически преобразуются в HTML. Это означает, что Вам не нужно знать HTML, чтобы что-то написать для веб-страницы, потому что Markdown переводит Ваши теги в HTML.
#
# Чтобы использовать Markdown, нужно просто применять простые теги к своему тексту.
#
# Рассмотрим основные примеры форматирования Markdown.

# %% [markdown]
# ### Заголовки

# %% [markdown]
# Делать заголовки в Markdown чрезвычайно просто. Всё, что вам нужно запомнить, - символ #, он же решётка, он же хеш. Уровень заголовка определяется количеством решёток в нём, всего их может быть шесть. Выглядит это так:

# %% [markdown]
# # Заголовок H1
# ## Заголовок H2
# ### Заголовок H3
# #### Заголовок H4
# ##### Заголовок H5
# ###### Заголовок H6

# %% [markdown]
# ### Текст

# %% [markdown]
# Помимо заголовков, Markdown поддерживает и простое форматирование текста. Его можно сделать курсивным или жирным при помощи звёздочек и подчёркиваний:

# %% [markdown]
# *Курсив* и _Курсив_
# **Жирный текст** и __Жирный текст__
# ***Жирный и курсивный текст***

# %% [markdown]
# ### Нумерованные и маркированные списки

# %% [markdown]
# Markdown позволяет создавать списки с любым уровнем вложенности. Маркированные списки делаются с помощью дефиса, проставляемого перед каждым пунктом:

# %% [markdown]
# - Первый пункт.
# - Второй пункт.
# - Третий пункт.

# %% [markdown]
# Нумерованные списки создаются точно так же, но с использованием цифр:

# %% [markdown]
# 1. Первый пункт.
# 2. Второй пункт.
# 3. Третий пункт

# %% [markdown]
# ### Горизонтальные линии

# %% [markdown]
# Линию можно использовать, чтобы разделять большие главы документа.
#
# Просто введите три раза (или больше) один из этих символов на клавиатуре: *, — или _, и в документ вставится горизонтальная линия.
#
# Если строкой выше над ней стоит ещё какой-то текст, он станет заголовком первого уровня.

# %% [markdown]
# ***
# Текст
# ---
# Текст
# ___
# Текст

# %% [markdown]
# ### Ссылки и изображения

# %% [markdown]
# В ячейки можно вставлять ссылки на страницы в интернете. Делается это вот так: [заголовок_ссылки] (сама_ссылка):

# %% [markdown]
# [Google](google.ru)

# %% [markdown]
# Аналогично в документ вставляются и изображения:

# %% [markdown]
# ![подпись](https://play-lh.googleusercontent.com/6UgEjh8Xuts4nwdWzTnWH8QtLuHqRMUB7dp24JYVE2xcYzq4HA8hFfcAbU-R-PC_9uA1)

# %% [markdown]
# ### Таблицы

# %% [markdown]
# Для таблиц используйте символы | и -.

# %% [markdown]
# | раз | два | три |
# |:----|:----|:----|
# | раз | два | три |

# %% [markdown]
# ### Код

# %% [markdown]
# Код выделяется символом `, то есть грависом. Окружив слово или фразу грависами, можно создавать строчки кода:

# %% [markdown]
# `Какой-то очень важный код.`

# %% [markdown]
# А три грависа позволяют отметить целый блок кода. Ещё это полезно, чтобы выделить целый абзац.

# %% [markdown]
# ```
# Целый абзац очень важного кода.
# И ещё строка.
# И ещё.
# ```

# %% [markdown]
# Подробное руководство по оформлению Markdown можно посмотреть по [ссылке](https://gist.github.com/Jekins/2bf2d0638163f1294637).

# %% [markdown]
# ## LaTeX

# %% [markdown]
# LaTeX — это система набора текста, которая включает функции, предназначенные для производства технической и научной документации.
#
# Используйте символ доллара, чтобы вставить математическую формулу. Для выделения и центрирования формул используйте два символа доллара.

# %% [markdown]
# Используйте символ доллара, чтобы вставить математическую формулу: $e^{i \pi} + 1 = 0$
#
# Формула Эйлера: $$ e^{i \pi} + 1 = 0 $$

# %% [markdown]
# Важные команды:
# 1.	**\\\** – добавление небольшого интервала.
# 2.	**\\\\** – переход на новую строку.
# 3.	**\frac{arg 1}{arg 2}** – отображение дробей.
# 4.	**^{}** – отображение надстрочных знаков.
# 5.	**_{}** – отображение индексов.
# 6.	**\sqrt[n]{arg}** – отображение корней.

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %% [markdown]
# Для вывода матриц используйте:

# %% [markdown]
# \begin{vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{vmatrix}

# %% [markdown]
# Подробное руководство по оформлению LaTeX можно посмотреть по [ссылке](https://ru.wikibooks.org/wiki/%D0%9C%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5_%D1%84%D0%BE%D1%80%D0%BC%D1%83%D0%BB%D1%8B_%D0%B2_LaTeX).

# %% [markdown]
# # Импорт, экспорт и сохранение блокнотов

# %% [markdown]
# Изменения в блокноте сохраняются автоматически, однако это можно сделать и вручную с помощью раздела меню «Файл».

# %% [markdown]
# ![Рисунок5.png](data:image/png;base64,...)

# %% [markdown]
# Для загрузки блокнота нажмите «Файл» — «Открыть блокнот».

# %% [markdown]
# ![Рисунок6.png](data:image/png;base64,...)

# %% [markdown]
# Файл блокнота можно загрузить с Google Диска, GitHub компьютера, для этого выберите соответствующий раздел.

# %% [markdown]
# ![Рисунок7.png](data:image/png;base64,...)

# %% [markdown]
# Файл блокнота можно скачать в формате IPYNB или PY.

# %% [markdown]
# ![Рисунок8.png](data:image/png;base64,...)

# %% [markdown]
# Для предоставления доступа к блокноту другим пользователям нажмите кнопку «Поделиться». Доступ можно предоставить как вручную добавляя пользователей по почте, так и разрешить доступ всем, у кого есть ссылка.

# %% [markdown]
# ![Рисунок9.png](data:image/png;base64,...)
